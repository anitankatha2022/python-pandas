# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\USER\\Desktop\\WAPS\\winemag-data_first150k.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# country            5
# description        0
# designation    45735
# points             0
# price          13695
# province           5
# region_1       25060
# region_2       89977
# variety            0
# winery             0
# dtype: int64

# %% [markdown]
# data is not clean

# %%
df.head(2)
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
#
#       region_1 region_2             variety                   winery
# 0  Napa Valley     Napa  Cabernet Sauvignon                    Heitz
# 1         Toro      NaN       Tinta de Toro  Bodega Carmen Rodríguez

# %%
df.shape
# Out:
# (150930, 11)

# %%
rows,columns=df.shape

# %%
columns
# Out:
# 11

# %%
df.tail()
# Out:
#         Unnamed: 0 country                                        description  \
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
#             designation  points  price            province           region_1  \
# 150925              NaN      91   20.0      Southern Italy  Fiano di Avellino
# 150926   Cuvée Prestige      91   27.0           Champagne          Champagne
# 150927    Terre di Dora      91   20.0      Southern Italy  Fiano di Avellino
# 150928  Grand Brut Rosé      90   52.0           Champagne          Champagne
# 150929              NaN      90   15.0  Northeastern Italy         Alto Adige
#
# ...

# %%
df[3:5]
# Out:
#    Unnamed: 0 country                                        description  \
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#   designation  points  price  province           region_1           region_2  \
# 3     Reserve      96   65.0    Oregon  Willamette Valley  Willamette Valley
# 4  La Brûlade      95   66.0  Provence             Bandol                NaN
#
#               variety                winery
# 3          Pinot Noir                 Ponzi
# 4  Provence red blend  Domaine de la Bégude

# %%
df[:]
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %%
df.price
# Out:
# 0         235.0
# 1         110.0
# 2          90.0
# 3          65.0
# 4          66.0
#           ...
# 150925     20.0
# 150926     27.0
# 150927     20.0
# 150928     52.0
# 150929     15.0
# Name: price, Length: 150930, dtype: float64

# %%
type[df.price]
# Out:
# type[0         235.0
# 1         110.0
# 2          90.0
# 3          65.0
# 4          66.0
#           ...
# 150925     20.0
# 150926     27.0
# 150927     20.0
# 150928     52.0
# 150929     15.0
# Name: price, Length: 150930, dtype: float64]

# %%
type(df["price"])
# Out:
# pandas.core.series.Series

# %%
 df["price"].max()
# Out:
# 2300.0

# %%
df["price"].std()
# Out:
# 36.32253619648552

# %%
df["price"].mean()
# Out:
# 33.13148249353299

# %%
df.describe()
# Out:
#           Unnamed: 0         points          price
# count  150930.000000  150930.000000  137235.000000
# mean    75464.500000      87.888418      33.131482
# std     43569.882402       3.222392      36.322536
# min         0.000000      80.000000       4.000000
# 25%     37732.250000      86.000000      16.000000
# 50%     75464.500000      88.000000      24.000000
# 75%    113196.750000      90.000000      40.000000
# max    150929.000000     100.000000    2300.000000

# %%
df[df.price<=8]
# Out:
#         Unnamed: 0   country  \
# 119            119  Portugal
# 776            776  Portugal
# 932            932  Portugal
# 995            995  Portugal
# 1004          1004  Portugal
# ...            ...       ...
# 150883      150883        US
# 150888      150888     Chile
# 150891      150891     Chile
# 150898      150898     Chile
# 150903      150903     Chile
#
#                                               description       designation  \
# 119     This broad, fruity wine brings out ripe berry ...  Convento da Vila
# 776     This is a herbal, earthy wine with as many tan...   D. Fuas Reserva
# 932     This is a herbal, earthy wine with as many tan...   D. Fuas Reserva
# 995     This is a dry sparkling wine with tannins, spi...      Plexus Tinto
# 1004    This wine balances swathes of ripe berry fruit...  Cal Monte da Cal
# ...                                                   ...               ...
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150930, step=1)
